# %% [markdown]
# ### Cet éxercice s'intéresse à l'identification de groupes cohérents au sein d'une population de souscripteurs d'assurance automobile dans plusieurs états des Etats Unis d'Amérique.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/JedhaBootcamp/FULL_STACK_24_WEEK_PROGRAM/master/S1.1%20--%20ML%20non-supervis%C3%A9%20-%20K-Means%20%26%20DBSCAN/S11-B%20-%20Pratique%20KMEANS%20%26%20DBSCAN/1.%20Pratique%20KMeans/Dataset/Auto_Insurance_Claims_Sample.csv?token=AGKBMYNOHDPYQWGYWOA3CJC7DWUYY")

# %%
dataset.shape
# Out:
# (9134, 26)

# %% [markdown]
# ### Quelles variables sont quantitatives ?
# Quelles variables sont qualitatives ?
# Quelles variables vous semblent les plus critiques pour assurer la viabilité d'un assureur ? Notez les quelques part ce seront nos "variables cibles" qui nous serviront par la suite à évaluer la qualité de notre segmentation clients.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
#  12  Location Code                  9134 non-null   object
#  13  Marital Status                 9134 non-null   object
#  14  Monthly Premium Auto           9134 non-null   int64
#  15  Months Since Last Claim        9134 non-null   int64
#  16  Months Since Policy Inception  9134 non-null   int64
#  17  Number of Open Complaints      9134 non-null   int64
#  18  Number of Policies             9134 non-null   int64
#  19  Policy Type                    9134 non-null   object
#  20  Policy                         9134 non-null   object
#  21  Claim Reason                   9134 non-null   object
#  22  Sales Channel                  9134 non-null   object
#  23  Total Claim Amount             9134 non-null   float64
#  24  Vehicle Class                  9134 non-null   object
#  25  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(18)
# memory usage: 1.8+ MB

# %%
dataset.head()
# variables quantitatives Claim Amount, Income, Monthly Premium Auto, Months Since Policy Inception, Number Of Open Complaints, Number Of Policies, Total Claim Amount
# categorical variables 'Customer', 'Country', 'StateCode', 'State', 'Response', 'Coverage', 'Education', 'EffectiveToDate', 'EmploymentStatus', 'Gender', 'LocationCode', 'MaritalStatus', 'MonthlyPremiumAuto', 'PolicyType', 'Policy', 'ClaimReason', 'SalesChannel', 'VehicleClass', 'VehicleSize'
# les variables critiques pour le bon fonctionnement de la compagnie d'assurance sont Claim amount, total claim amount, et dans une moindre mesure Monthly Premium Auto
# Out:
#   Customer Country State Code  ... Total Claim Amount  Vehicle Class Vehicle Size
# 0  BU79786      US         KS  ...         384.811147   Two-Door Car      Medsize
# 1  QZ44356      US         NE  ...        1131.464935  Four-Door Car      Medsize
# 2  AI49188      US         OK  ...         566.472247   Two-Door Car      Medsize
# 3  WW63253      US         MO  ...         529.881344            SUV      Medsize
# 4  HB64268      US         KS  ...         138.130879  Four-Door Car      Medsize
#
# [5 rows x 26 columns]

# %% [markdown]
# ###  Créer un nouveau dataset en excluant les variables relatives à l'accident, nous conserverons ainsi pour l'étude uniquement les variables qui décrivent les souscripteurs. Traîtez ce nouveau dataset afin de remplacer les variables catégorielles en une collection de variables numériques.

# %%
dataset_matrix = pd.get_dummies(dataset[[
                                        'Response', 'Coverage', 'Education', 'EmploymentStatus',
               'Gender', 'Income', 'Location Code', 'Marital Status', 'State',
               'Monthly Premium Auto', 'Months Since Last Claim',
               'Months Since Policy Inception', 'Number of Open Complaints',
               'Number of Policies', 'Policy Type', 'Policy',
               'Sales Channel', 'Vehicle Class', 'Vehicle Size'
]])

# %%
dataset["State"].value_counts()
# Out:
# Missouri    3150
# Iowa        2601
# Nebraska    1703
# Oklahoma     882
# Kansas       798
# Name: State, dtype: int64

# %%
dataset_matrix.groupby(dataset["State"]).mean()
# On observe pas de différence significatives entre les individus des différents états, on peut donc considérer de faire une étude commune à tous les états
# Out:
#                 Income  ...  Vehicle Size_Small
# State                   ...
# Iowa      37557.283353  ...            0.200308
# Kansas    38122.733083  ...            0.176692
# Missouri  37558.946667  ...            0.187302
# Nebraska  37405.402231  ...            0.184968
# Oklahoma  38369.605442  ...            0.223356
#
# [5 rows x 59 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler as sc

dataset_matrix_num_scaled = sc().fit_transform(
    dataset[[
      'Income',
      'Monthly Premium Auto', 'Months Since Last Claim',
      'Months Since Policy Inception', 'Number of Open Complaints',
      'Number of Policies'
    ]])
dataset_matrix_num_scaled = pd.DataFrame(
    dataset_matrix_num_scaled,
    columns=[
      'Income',
      'Monthly Premium Auto', 'Months Since Last Claim',
      'Months Since Policy Inception', 'Number of Open Complaints',
      'Number of Policies'
    ]
)

dataset_matrix_cat = pd.get_dummies(
    dataset[[
      'Response',
      'Coverage', 'Education', 'EmploymentStatus',
      'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy',
      'Sales Channel', 'Vehicle Class', 'Vehicle Size'
   ]])

# %%
dataset_matrix_scaled = pd.concat([dataset_matrix_num_scaled, dataset_matrix_cat], axis=1)

# %%
kmeans = KMeans(n_clusters=2)
customer_kmean_cluster_2 = kmeans.fit_predict(dataset_matrix_scaled)
dataset_matrix.groupby(customer_kmean_cluster_2).mean()

# un des clusters contient la quasi totalité des employed, et l'autre contient l'intégralité des autres catégories d'employement status
# Out:
#          Income  Monthly Premium Auto  ...  Vehicle Size_Medsize  Vehicle Size_Small
# 0  57524.849091             92.674545  ...              0.710727            0.191273
# 1   7588.288112             94.043753  ...              0.692075            0.195927
#
# [2 rows x 59 columns]

# %%
employees = dataset_matrix_scaled.loc[dataset_matrix_scaled["EmploymentStatus_Employed"]==1,
                                      ]

# %%
employees
# Out:
#         Income  Monthly Premium Auto  ...  Vehicle Size_Medsize  Vehicle Size_Small
# 0     0.612827             -0.703925  ...                     1                   0
# 2     0.365710              0.429596  ...                     1                   0
# 4     0.203390             -0.587666  ...                     1                   0
# 5     0.831010             -0.703925  ...                     1                   0
# 6     0.582411             -0.762054  ...                     1                   0
# ...        ...                   ...  ...                   ...                 ...
# 9127  0.945072             -0.849248  ...                     0                   1
# 9128  0.332594              0.313337  ...                     0                   0
# 9129  1.128558             -0.587666  ...                     1                   0
# 9130 -0.528450             -0.413278  ...                     1                   0
# 9132 -0.517356              0.080820  ...                     0                   0
#
# [5698 rows x 54 columns]

# %%
# Ns = range(1, 10)
# kmeans = [KMeans(n_clusters=i) for i in Ns]
# scores = [kmean.fit(employees).inertia_ for kmean in kmeans]

Ns = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in Ns]
scores = [kmean.fit(employees).inertia_ for kmean in kmeans]

# %%
plt.plot(Ns, scores)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.show()

# nous retenons 6 clusters pour la sous population des employed

# %% [markdown]
#  ### Afin de pouvoir visualiser et analyser les différentes classes, nous procéderons à une PCA à 3 composantes. On analysera ces composantes afin de pouvoir les interpréter en termes des variables d'origine. Puis on visualisera les différentes classes selon les axes définis par les composantes principales afin de décrire les clusters.

# %%
kmeans6 = KMeans(n_clusters=6)
employee_kmean6 = kmeans6.fit_predict(employees)

from sklearn.decomposition import PCA 
pca3 = PCA(n_components=3)
employee_reduced = pca3.fit_transform(employees)

pca3.explained_variance_ratio_

# les 3 premières variables ne sont pas ultra explicatives (env. 30% de l'inertie seulement)
employee_kmean6
# Out:
# array([2, 1, 1, ..., 4, 1, 2], dtype=int32)

# %%
# Get the PCA components (loadings)
PCs = pca3.components_

# Use quiver to generate the basic plot
fig = plt.figure(figsize=(10,10))
plt.quiver(np.zeros(PCs.shape[1]), np.zeros(PCs.shape[1]),
           PCs[0,:], PCs[1,:], 
           angles='xy', scale_units='xy', scale=1)

# Add labels based on feature names (here just numbers)
feature_names = employees.columns  # une liste avec les noms de vos variables d'origine
for i,j,z in zip(PCs[1,:]+0.02, PCs[0,:]+0.02, feature_names):
    plt.text(j, i, z, ha='center', va='center')

# Add unit circle
circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
plt.gca().add_artist(circle)

# Ensure correct aspect ratio and axis limits
plt.axis('equal')
plt.xlim([-1.0,1.0])
plt.ylim([-1.0,1.0])

# Label axes
plt.xlabel('PC 1')
plt.ylabel('PC 2')

# les variables les plus pertinentes pour expliquer les données sont Number of Policies et Monthly Premium Auto
# PC 1 -> + Month since last claim + Number of policies + number of open complaints - months since policy inception
# PC 2 -> + monthly premium auto
# Out:
# Text(0, 0.5, 'PC 2')

# %%
# Get the PCA components (loadings)
PCs = pca3.components_

# Use quiver to generate the basic plot
fig = plt.figure(figsize=(10,10))
plt.quiver(np.zeros(PCs.shape[1]), np.zeros(PCs.shape[1]),
           PCs[1,:], PCs[2,:], 
           angles='xy', scale_units='xy', scale=1)

# Add labels based on feature names (here just numbers)
feature_names = employees.columns  # une liste avec les noms de vos variables d'origine
for i,j,z in zip(PCs[2,:]+0.02, PCs[1,:]+0.02, feature_names):
    plt.text(j, i, z, ha='center', va='center')

# Add unit circle
circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
plt.gca().add_artist(circle)

# Ensure correct aspect ratio and axis limits
plt.axis('equal')
plt.xlim([-1.0,1.0])
plt.ylim([-1.0,1.0])

# Label axes
plt.xlabel('PC 3')
plt.ylabel('PC 2')

# les prochaines variables les plus importantes sont Months Since Last Claim et Months Since Policy Inception
# PC2 -> + number of open complaints - Number of policies
# Out:
# Text(0, 0.5, 'PC 2')

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(employee_reduced[:,0], employee_reduced[:,1], palette =["red","blue","green","yellow","pink","black"], hue = employee_kmean6)

# groupe 0 1 3 4 confondus selon PC1 et PC2
# groupe 2 beaucoup plus élevé selon PC1 ils représentent des nouveaux clients qui sont très bien assurés ont de nombreuses open complaints et de nombreux mois depuis leur dernière plainte
# groupe 5 beaucoup plus bas selon l'axe PC2 représente le groupe dont le premium mensuel est le plus faible

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(employee_reduced[:,0], employee_reduced[:,2], palette =["red","blue","green","yellow","pink","black"], hue = employee_kmean6)

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(employee_reduced[:,1], employee_reduced[:,2], palette =["red","blue","green","yellow","pink","black"], hue = employee_kmean6)
